# %% [markdown]
# # **Brain Stroke Dataset Classification Prediction**

# %% [markdown]
# # **Import Library**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # **Business Understanding**

# %% [markdown]
# ## **Business Objective**
#
# Analisis pada dataset Brain Stroke bertujuan untuk memahami faktor-faktor kesehatan yang berhubungan dengan kejadian stroke. Fokus utama analisis ini meliputi usia (age), hipertensi (hypertension), penyakit jantung (heart_disease), kadar gula darah rata-rata (avg_glucose_level), BMI, dan kebiasaan merokok (smoking_status).
#
# Melalui analisis ini diharapkan dapat diketahui faktor mana yang memiliki pengaruh paling signifikan terhadap kejadian stroke sehingga dapat menjadi dasar dalam upaya pencegahan maupun pengembangan model prediksi di tahap selanjutnya.

# %% [markdown]
# ## **Assess Situation**
# Dataset Brain Stroke berisi data pasien dengan berbagai atribut kesehatan serta satu variabel target yaitu stroke (0 = tidak stroke, 1 = stroke).
#
# Berdasarkan pemeriksaan awal, dataset berada dalam kondisi yang cukup baik:
# * Tidak terdapat missing value
# * Tidak terdapat data duplikat
# * Tidak ditemukan inkonsistensi kategori yang signifikan
# * Sebagian besar tipe data sudah sesuai dengan jenis variabel
#
# Pada tahap Data Preparation selanjutnya dilakukan penyesuaian tipe data serta verifikasi ulang kualitas data untuk memastikan dataset siap digunakan pada proses analisis dan pemodelan.

# %% [markdown]
# ## **Analytic Goals**
#
# Tujuan analisis yang ingin dilakukan adalah:
# *   Melihat hubungan usia dengan risiko stroke
# *   Menganalisis pengaruh hipertensi terhadap stroke
# *   Menganalisis pengaruh penyakit jantung terhadap stroke
# *   Melihat pengaruh kadar gula darah terhadap stroke
# *   Menganalisis pengaruh BMI terhadap stroke
# *   Menganalisis pengaruh kebiasaan merokok terhadap stroke

# %% [markdown]
# ## **Project Plan**
#
# Tahapan analisis data yang akan dilakukan meliputi:
# *   Memahami struktur dataset dan tipe data
# *   Mengimpor dataset Brain Stroke
# *   Membersihkan data (missing value, data duplikat, dan nilai tidak valid)
# *   Melakukan analisis statistik deskriptif
# *   Membuat visualisasi untuk melihat pola faktor risiko stroke
# *   Menarik kesimpulan dan insight dari hasil analisis

# %% [markdown]
# # **Data Understanding**

# %% [markdown]
# ## **Memuat Dataset**

# %%
file = '/content/drive/MyDrive/dataset praktikum/brain_stroke.csv'
df = pd.read_csv(file)
df.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1    Male  80.0             0              1          Yes        Private
# 2  Female  49.0             0              0          Yes        Private
# 3  Female  79.0             1              0          Yes  Self-employed
# 4    Male  81.0             0              0          Yes        Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             105.92  32.5     never smoked       1
# 2          Urban             171.23  34.4           smokes       1
# 3          Rural             174.12  24.0     never smoked       1
# 4          Urban             186.21  29.0  formerly smoked       1

# %% [markdown]
# ## **Informasi Dasar**

# %% [markdown]
# Dataset terdiri dari sejumlah baris data pasien dengan beberapa variabel numerik dan kategorikal. Kolom target dalam analisis ini adalah stroke.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4981 entries, 0 to 4980
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             4981 non-null   object
#  1   age                4981 non-null   float64
#  2   hypertension       4981 non-null   int64
#  3   heart_disease      4981 non-null   int64
#  4   ever_married       4981 non-null   object
#  5   work_type          4981 non-null   object
#  6   Residence_type     4981 non-null   object
#  7   avg_glucose_level  4981 non-null   float64
#  8   bmi                4981 non-null   float64
#  9   smoking_status     4981 non-null   object
#  10  stroke             4981 non-null   int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 428.2+ KB

# %% [markdown]
# Dataset terdiri dari 4981 baris dan 11 kolom.
# Terdapat:
# *   3 kolom bertipe float64 (age, avg_glucose_level, bmi)
# *   3 kolom bertipe int64 (hypertension, heart_disease, stroke)
# *   5 kolom bertipe object/kategorikal
#
# Kolom target dalam analisis ini adalah stroke.
#
# Semua kolom memiliki jumlah data yang sama (4981 non-null), sehingga tidak terdapat data kosong.

# %% [markdown]
# ## **Informasi Statistik Deskriptif**

# %%
df.describe()
# Out:
#                age  hypertension  heart_disease  avg_glucose_level  \
# count  4981.000000   4981.000000    4981.000000        4981.000000
# mean     43.419859      0.096165       0.055210         105.943562
# std      22.662755      0.294848       0.228412          45.075373
# min       0.080000      0.000000       0.000000          55.120000
# 25%      25.000000      0.000000       0.000000          77.230000
# 50%      45.000000      0.000000       0.000000          91.850000
# 75%      61.000000      0.000000       0.000000         113.860000
# max      82.000000      1.000000       1.000000         271.740000
#
#                bmi       stroke
# count  4981.000000  4981.000000
# mean     28.498173     0.049789
# std       6.790464     0.217531
# min      14.000000     0.000000
# 25%      23.700000     0.000000
# 50%      28.100000     0.000000
# 75%      32.600000     0.000000
# max      48.900000     1.000000

# %% [markdown]
# *   Usia (age) memiliki rentang dari usia sangat muda hingga lanjut usia, dengan rata-rata berada pada kategori dewasa.
# *   Avg_glucose_level memiliki rentang nilai yang cukup lebar, menunjukkan adanya variasi kadar gula antar pasien.
# *   BMI menunjukkan variasi yang cukup tinggi antar individu.
#
# Perbandingan antara mean dan median pada avg_glucose_level menunjukkan distribusi cenderung right-skewed, yang mengindikasikan adanya beberapa nilai tinggi yang memengaruhi rata-rata.

# %% [markdown]
# # **Data Preparation**

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom              Persentase Outliers
# age                           0.000000
# hypertension                  9.616543
# heart_disease                 5.520980
# avg_glucose_level            12.085927
# bmi                           0.863280
# stroke                        4.978920

# %% [markdown]
# ## **Data Type Check**

# %% [markdown]
# Seluruh kolom sudah memiliki tipe data yang sesuai dengan jenis variabelnya. Tidak diperlukan konversi tipe data.

# %%
df.dtypes
# Out:
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %% [markdown]
# Penanganan Tipe Data

# %%
df['hypertension'] = df['hypertension'].astype('category')
df['heart_disease'] = df['heart_disease'].astype('category')
df['stroke'] = df['stroke'].astype('category')

# %% [markdown]
# Kolom hypertension, heart_disease, dan stroke diubah menjadi tipe data category karena nilai pada kolom tersebut hanya merepresentasikan kategori (0 = tidak, 1 = ya), bukan nilai numerik kontinu. Perubahan tipe data dilakukan agar struktur data lebih sesuai dengan makna variabel serta mempermudah proses analisis selanjutnya.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4981 entries, 0 to 4980
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             4981 non-null   object
#  1   age                4981 non-null   float64
#  2   hypertension       4981 non-null   category
#  3   heart_disease      4981 non-null   category
#  4   ever_married       4981 non-null   object
#  5   work_type          4981 non-null   object
#  6   Residence_type     4981 non-null   object
#  7   avg_glucose_level  4981 non-null   float64
#  8   bmi                4981 non-null   float64
#  9   smoking_status     4981 non-null   object
#  10  stroke             4981 non-null   category
# dtypes: category(3), float64(3), object(5)
# memory usage: 326.4+ KB

# %% [markdown]
# ## **Cek Inconsistent Values**

# %%
print(df['gender'].unique())
# Out:
# ['Male' 'Female']

# %% [markdown]
# Penjelasan:
# Kolom gender memiliki dua kategori yaitu Male dan Female. Tidak ditemukan variasi penulisan yang berbeda sehingga tidak terdapat inkonsistensi pada kolom ini.
#
# ---

# %%
print(df['work_type'].unique())
# Out:
# ['Private' 'Self-employed' 'Govt_job' 'children']

# %% [markdown]
# Penjelasan:
# Kolom work_type memiliki beberapa kategori pekerjaan seperti Private, Self-employed, Govt_job, dan lainnya. Seluruh kategori sudah konsisten dan tidak ditemukan perbedaan format penulisan.
#
# ---

# %%
print(df['smoking_status'].unique())
# Out:
# ['formerly smoked' 'never smoked' 'smokes' 'Unknown']

# %% [markdown]
# Penjelasan:
# Kolom smoking_status memiliki beberapa kategori seperti never smoked, formerly smoked, smokes, dan kemungkinan kategori lainnya sesuai output. Tidak ditemukan inkonsistensi format penulisan, sehingga data pada kolom ini sudah rapi dan siap dianalisis.
#
# ---

# %%
print(df['ever_married'].unique())
# Out:
# ['Yes' 'No']

# %% [markdown]
# Penjelasan:
# Kolom ever_married memiliki dua kategori yaitu Yes dan No. Tidak terdapat variasi huruf besar/kecil atau penulisan berbeda, sehingga tidak ditemukan inkonsistensi.
#
# ---

# %%
print(df['Residence_type'].unique())
# Out:
# ['Urban' 'Rural']

# %% [markdown]
# Penjelasan:
# Kolom Residence_type memiliki dua kategori yaitu Urban dan Rural. Format penulisan sudah konsisten dan tidak ditemukan perbedaan penulisan yang dapat menyebabkan kesalahan analisis.

# %% [markdown]
# ## **Missing Values**

# %% [markdown]
# Tahapan:
#
# *   Menggunakan fungsi isna() untuk mendeteksi nilai kosong (NaN).
# *   Menjumlahkan seluruh nilai kosong di setiap kolom dengan sum().
# *   Mengevaluasi apakah ada kolom yang memiliki nilai selain 0.

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                    Null Ratio in %
# gender                         0.0
# age                            0.0
# hypertension                   0.0
# heart_disease                  0.0
# ever_married                   0.0
# work_type                      0.0
# Residence_type                 0.0
# avg_glucose_level              0.0
# bmi                            0.0
# smoking_status                 0.0
# stroke                         0.0

# %% [markdown]
# Penjelasan:
# Hasil pengecekan menunjukkan seluruh kolom memiliki nilai 0 pada missing values. Artinya dataset tidak memiliki data kosong sehingga tidak diperlukan proses imputasi atau penghapusan baris.

# %% [markdown]
# ## **Duplicated Values**

# %% [markdown]
# Tahapan:
# *   Menggunakan fungsi duplicated() untuk mendeteksi baris yang memiliki isi data sama persis.
# *   Menampilkan baris yang terduplikasi.
# *   Mengevaluasi apakah terdapat data yang perlu dihapus.

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [gender, age, hypertension, heart_disease, ever_married, work_type, Residence_type, avg_glucose_level, bmi, smoking_status, stroke]
# Index: []

# %% [markdown]
# Tidak ditemukan data yang terduplikasi. Setiap baris merepresentasikan satu individu secara unik. Hal ini penting karena duplikasi dapat menyebabkan bias dalam analisis, terutama saat menghitung distribusi atau hubungan antar variabel.

# %% [markdown]
# ## **Outliers Values**

# %% [markdown]
# Pada tahap ini dilakukan pemeriksaan nilai ekstrem (outliers) pada seluruh kolom numerik menggunakan metode Interquartile Range (IQR). Pemeriksaan ini bertujuan untuk mengetahui apakah terdapat nilai yang berada jauh di luar distribusi normal data dan berpotensi memengaruhi hasil analisis.

# %%
# Cek Outliers menggunakan metode IQR

results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    percent_outliers = (len(outliers) / len(df)) * 100
    results.append({'Kolom': col, 'Persentase Outliers (%)': percent_outliers})

results_df = pd.DataFrame(results)
results_df
# Out:
#                Kolom  Persentase Outliers (%)
# 0                age                      0.0
# 1  avg_glucose_level                      0.0
# 2                bmi                      0.0

# %%
results_df.sort_values(by='Persentase Outliers (%)', ascending=False)
# Out:
#                Kolom  Persentase Outliers (%)
# 0                age                      0.0
# 1  avg_glucose_level                      0.0
# 2                bmi                      0.0

# %% [markdown]
# Variabel avg_glucose_level dan bmi memiliki nilai outlier sehingga dilakukan penanganan menggunakan metode IQR dengan membatasi nilai ekstrem agar distribusi data menjadi lebih stabil tanpa menghapus data. Setelah penanganan dilakukan, tidak ditemukan lagi nilai outlier pada kolom tersebut.
#
#
# Variabel age tidak memiliki outlier sehingga tidak memerlukan penanganan lebih lanjut.

# %% [markdown]
# Penanganan Data

# %%
columns_to_impute = ["avg_glucose_level", "bmi"]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %% [markdown]
# Outlier ditangani menggunakan metode IQR untuk membatasi nilai yang terlalu tinggi atau terlalu rendah agar tidak mempengaruhi hasil analisis. Metode ini digunakan supaya data tetap lengkap tanpa perlu menghapus baris data, sehingga distribusi data menjadi lebih stabil.

# %% [markdown]
# ### **Visualisasi Outlier (Boxplot)**

# %%
plt.figure(figsize=(6,4))
sns.boxplot(y=df['avg_glucose_level'])
plt.title('Boxplot Avg Glucose Level')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(y=df['bmi'])
plt.title('Boxplot BMI')
plt.show()

# %% [markdown]
# Penjelasan Visualisasi
#
# Setelah dilakukan penanganan menggunakan metode IQR, visualisasi boxplot menunjukkan bahwa tidak terdapat lagi nilai ekstrem di luar batas distribusi. Hal ini menunjukkan proses penanganan outlier berhasil membuat distribusi data lebih stabil.

# %% [markdown]
# # **Data Construction**

# %%
def kategori_stroke(nilai):
    if nilai == 1:
        return "Stroke"
    else:
        return "Tidak Stroke"

df['kategori_stroke'] = df['stroke'].apply(kategori_stroke)

# %%
df[['stroke','kategori_stroke']].head()
# Out:
#   stroke kategori_stroke
# 0      1          Stroke
# 1      1          Stroke
# 2      1          Stroke
# 3      1          Stroke
# 4      1          Stroke

# %% [markdown]
# Data construction dilakukan dengan membuat kolom baru bernama kategori_stroke yang berasal dari kolom stroke. Nilai numerik 0 dan 1 diubah menjadi kategori Tidak Stroke dan Stroke agar data lebih mudah dipahami serta mempermudah interpretasi hasil analisis dibandingkan hanya menggunakan angka.

# %% [markdown]
# # **Data Reduction**

# %%
df = df.drop('stroke', axis=1)

# %% [markdown]
# Data reduction dilakukan dengan menghapus kolom stroke karena informasi tersebut sudah direpresentasikan dalam kolom kategori_stroke. Penghapusan dilakukan untuk mengurangi redundansi dan membuat dataset lebih ringkas.

# %% [markdown]
# # **Eksplorasi Data (EDA)**

# %% [markdown]
# ## **Comparison / Perbandingan**

# %% [markdown]
# Analisis:
# >  Perbandingan dilakukan untuk melihat jumlah pasien yang mengalami stroke dan tidak mengalami stroke.
#
# Tujuan:
# >  Untuk mengetahui distribusi target dan melihat apakah dataset seimbang atau tidak.
#
# Visualisasi:
# >  Bar Chart (Grafik Batang)

# %%
stroke_counts = df['kategori_stroke'].value_counts()

plt.figure()
stroke_counts.plot(kind='bar')
plt.title('Perbandingan Stroke dan Tidak Stroke')
plt.xlabel('Stroke (0=Tidak, 1=Ya)')
plt.ylabel('Jumlah Pasien')
plt.show()

# %% [markdown]
# Jumlah pasien tidak stroke jauh lebih banyak dibandingkan pasien stroke. Hal ini menunjukkan bahwa dataset bersifat tidak seimbang (imbalanced), di mana kasus stroke merupakan kelompok minoritas.

# %% [markdown]
# ## **Composition / Komposisi**

# %% [markdown]
# Analisis:
# >  Komposisi dilakukan untuk melihat proporsi pasien stroke terhadap keseluruhan data.
#
# Tujuan:
# >  Untuk mengetahui persentase kejadian stroke dalam dataset.
#
# Visualisasi:
# >  Pie Chart

# %%
plt.figure()
stroke_counts.plot(kind='pie', autopct='%1.1f%%')
plt.title('Komposisi Stroke')
plt.ylabel('')
plt.show()

# %% [markdown]
# Proporsi pasien stroke lebih kecil dibandingkan tidak stroke. Hal ini menunjukkan bahwa kejadian stroke dalam dataset tergolong rendah dibandingkan populasi keseluruhan.

# %% [markdown]
# ## **Distribution / Distribusi**

# %% [markdown]
# Analisis:
# >  Distribusi dilakukan pada variabel usia (age) untuk memahami pola penyebaran usia pasien.
#
# Tujuan:
# >  Untuk melihat kelompok usia mana yang paling dominan dan hubungannya terhadap risiko stroke.
#
# Visualisasi:
# >  Histogram

# %%
plt.figure()
df['age'].plot(kind='hist', bins=30)
plt.title('Distribusi Usia')
plt.xlabel('Age')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# Sebagian besar pasien berada pada usia dewasa hingga lanjut usia. Kelompok usia yang lebih tinggi cenderung memiliki risiko stroke yang lebih besar.

# %% [markdown]
# ## **Relationship / Hubungan**

# %% [markdown]
# Analisis:
# >  Analisis hubungan dilakukan antara variabel numerik (age, avg_glucose_level, bmi) dengan stroke untuk melihat kekuatan hubungan antar variabel.
#
# Tujuan:
# >  Untuk mengetahui faktor mana yang memiliki hubungan paling kuat terhadap kejadian stroke.
#
# Visualisasi:
# >  Heatmap Korelasi

# %%
corr_data = df[['age', 'avg_glucose_level', 'bmi']].corr()

plt.figure()
sns.heatmap(corr_data, annot=True)
plt.title('Heatmap Korelasi')
plt.show()

# %% [markdown]
# Usia memiliki korelasi positif paling kuat terhadap stroke dibandingkan variabel numerik lainnya. Kadar gula darah dan BMI juga memiliki hubungan, namun relatif lebih lemah.

# %%
pd.crosstab(df['hypertension'], df['kategori_stroke'])
# Out:
# kategori_stroke  Tidak Stroke  Stroke
# hypertension
# 0                        4320     182
# 1                         413      66

# %% [markdown]
# Penjelasan: Pasien dengan hipertensi menunjukkan proporsi stroke lebih besar dibandingkan pasien tanpa hipertensi, sehingga hipertensi dapat dianggap sebagai faktor risiko yang berhubungan dengan stroke.

# %%
pd.crosstab(df['heart_disease'], df['kategori_stroke'])
# Out:
# kategori_stroke  Tidak Stroke  Stroke
# heart_disease
# 0                        4505     201
# 1                         228      47

# %% [markdown]
# Penjelasan: Pasien dengan riwayat penyakit jantung menunjukkan proporsi stroke yang lebih besar.

# %%
pd.crosstab(df['smoking_status'], df['kategori_stroke'])
# Out:
# kategori_stroke  Tidak Stroke  Stroke
# smoking_status
# Unknown                  1453      47
# formerly smoked           797      70
# never smoked             1749      89
# smokes                    734      42

# %% [markdown]
# Penjelasan: Beberapa kategori perokok menunjukkan jumlah stroke lebih tinggi dibandingkan non-perokok.

# %% [markdown]
# # **Visualisasi Data**

# %% [markdown]
# Visualisasi Data\
# Visualisasi data dilakukan untuk melihat pola dan hubungan antar variabel pada dataset Brain Stroke. Dengan menggunakan berbagai jenis grafik, faktor-faktor yang berhubungan dengan kejadian stroke dapat lebih mudah diamati.

# %% [markdown]
# ## **Bar Chart**

# %% [markdown]
# **Perbandingan Stroke vs Tidak Stroke**

# %% [markdown]
# Grafik menunjukkan jumlah pasien yang mengalami stroke dan tidak stroke. Terlihat bahwa jumlah pasien tidak stroke lebih banyak dibandingkan pasien stroke.

# %%
stroke_count = df['kategori_stroke'].value_counts().head(5).sort_values(ascending=False)

plt.figure(figsize=(10, 6))
plt.bar(stroke_count.index, stroke_count.values, color='skyblue')
plt.xlabel('Stroke (0 = Tidak, 1 = Ya)')
plt.ylabel('Jumlah Pasien')
plt.title('Jumlah Pasien Stroke dan Tidak Stroke')
plt.xticks(rotation=90, ha='center')
plt.tight_layout()
plt.show()

# %% [markdown]
# Bar chart menunjukkan perbandingan jumlah pasien yang mengalami stroke dan tidak stroke. Terlihat bahwa jumlah pasien tidak stroke lebih banyak dibandingkan pasien stroke, sehingga faktor risiko seperti usia, hipertensi, dan kadar gula darah perlu diperhatikan untuk membantu pencegahan stroke.

# %% [markdown]
# ## **Pie Chart**

# %% [markdown]
# **Komposisi Pasien Stroke**

# %% [markdown]
# Pie chart digunakan untuk melihat persentase pasien stroke dan tidak stroke dalam dataset.

# %%
stroke_pie = df['kategori_stroke'].value_counts()

plt.figure(figsize=(10, 6))
plt.pie(stroke_pie,
        labels=stroke_pie.index,
        autopct='%1.1f%%',
        colors=['lightcoral','lightblue'])
plt.title('Komposisi Pasien Stroke')
plt.show()

# %% [markdown]
# Pie chart menunjukkan bahwa persentase pasien tidak stroke lebih besar dibandingkan pasien stroke. Hal ini menunjukkan bahwa sebagian besar pasien dalam dataset berada pada kondisi tidak stroke.

# %% [markdown]
# ## **Histogram**

# %% [markdown]
# **Distribusi Usia Pasien**

# %% [markdown]
# Distribusi Usia Pasien

# %%
age_distribution = df['age']

plt.figure(figsize=(8, 5))
plt.hist(age_distribution, bins=20, color='blue', edgecolor='black')
plt.title('Distribusi Usia Pasien')
plt.xlabel('Usia')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# Histogram menunjukkan bahwa sebagian besar pasien berada pada rentang usia dewasa hingga lanjut usia. Hal ini menunjukkan bahwa usia dapat menjadi salah satu faktor yang berkaitan dengan risiko stroke.

# %% [markdown]
# ## **Box Plot**

# %% [markdown]
# **Distribusi BMI Berdasarkan Status Stroke**

# %% [markdown]
# Boxplot digunakan untuk melihat distribusi nilai BMI pada pasien stroke dan tidak stroke.

# %%
stroke_category = df['kategori_stroke'].value_counts().head(5).index
stroke_filtered = df[df['kategori_stroke'].isin(stroke_category)]

plt.figure(figsize=(12, 7))
sns.boxplot(x='kategori_stroke', y='bmi', data=stroke_filtered,
            palette='viridis', order=stroke_category,
            hue='kategori_stroke', legend=False)

plt.title('Distribusi BMI Berdasarkan Status Stroke')
plt.xlabel('Stroke (0 = Tidak, 1 = Ya)')
plt.ylabel('BMI')
plt.xticks(rotation=90, ha='center')
plt.tight_layout()
plt.show()

# %% [markdown]
# Boxplot menunjukkan variasi nilai BMI pada pasien stroke dan tidak stroke. Nilai BMI yang lebih tinggi dapat menjadi salah satu faktor risiko kesehatan yang perlu diperhatikan.

# %% [markdown]
# ## **Scatter Plot**

# %% [markdown]
# **Hubungan Usia dan Kadar Gula Darah**

# %% [markdown]
# Scatter plot digunakan untuk melihat hubungan antara usia pasien dan kadar gula darah rata-rata.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='age', y='avg_glucose_level', hue='kategori_stroke', data=df)

plt.title('Hubungan Usia dan Kadar Gula Darah')
plt.xlabel('Usia')
plt.ylabel('Avg Glucose Level')
plt.legend(title='Kategori Stroke')

plt.show()

# %% [markdown]
# Scatter plot menunjukkan bahwa beberapa pasien dengan usia yang lebih tinggi memiliki kadar gula darah yang lebih tinggi, sehingga pemantauan kesehatan sangat penting untuk mengurangi risiko stroke.

# %% [markdown]
# ## **Heatmap**

# %% [markdown]
# **Korelasi Variabel Numerik**

# %% [markdown]
# Heatmap digunakan untuk melihat hubungan atau korelasi antar variabel numerik dalam dataset.

# %%
numeric_corr = df[['age','avg_glucose_level','bmi']].corr()

plt.figure(figsize=(8, 6))
sns.heatmap(data=numeric_corr,
            annot=True,
            cmap='viridis',
            fmt='.2f')

plt.title('Korelasi Variabel Numerik')
plt.show()

# %% [markdown]
# Heatmap menunjukkan hubungan antar variabel numerik seperti usia, kadar gula darah, dan BMI. Terlihat bahwa terdapat hubungan antar beberapa variabel kesehatan yang dapat membantu memahami faktor risiko yang berkaitan dengan stroke.

# %% [markdown]
# # **Menyimpan Dataset**

# %%
df.to_csv('[clean]brain_stroke.csv', index=False)
